# %%
import csv
details=['Unique ID','Name','Gender','Age','Occupation','salary','Hobby','Dislike','Location']
existing_user=[[10001,"Akash",'Male',26,'Software engineer',100000,'Reading books','Cakes','Bangalore'],
               [10002,'Anwar','Male',28,'Business',150000,'Playing games','Advice','Chennai'],
               [10003,'Malar','Female',24,'HR',200000,'Cooking','Spicy foods','Coimbatore'],
               [10004,'Reyhan','Female',25,'Tailor',50000,'Watching animes','Action movies','Madurai'],
               [10005,'David','Male',29,'Electrical engineer',250000,'Swimming','Nonveg','Trichy']]
def insertion():
    for i in details:
        if i!='Unique ID' and i!="Age" and i!='salary':
            user_details.append(input(f'Enter the {i}:').capitalize())
        elif i=='Age'or i=='salary':
            user_details.append(int(input(f'Enter the {i}:')))
        else:
            for j in range(len(existing_user)):
                Id=existing_user[j][0]
                if j==(len(existing_user)-1):
                    Id+=1
            user_details.append(Id)
def modification():
    pass
def retrival():
    for i in range(len(existing_user)):
        ordered_list.append(existing_user[i][1])
    l=sorted(ordered_list)
    for j in l:
        for k in existing_user:
            if j in k:
                print()
                for i in range(len(details)):
                    print(f'{details[i]}:{k[i]}')
def searching():
    name_of_the_person=input("Enter the name: ").capitalize()
    for i in existing_user:
        if name_of_the_person in i:
            print()
            for j in range(len(details)):
                print(f'{details[j]}:{i[j]}')
def recommendation():
    your_gender=input('Enter your gender:').capitalize()
    your_age=int(input('Enter your age:'))
    your_hobby=input('Enter your hobby:').capitalize()
    your_dislike=input('Enter your dislike:').capitalize()
    count_of_matches=[]
    for i in existing_user:
        count_of_particular=0
        if your_age in i:
            count_of_particular+=1
        if your_hobby in i:
            count_of_particular+=1
        if your_dislike in i:
            count_of_particular+=1
        if your_gender in i:
            count_of_particular=0
        else:
            count_of_particular+=1
        count_of_matches.append(count_of_particular)
    x=existing_user[count_of_matches.index(max(count_of_matches))]
    print()
    for i in range(len(details)):
        print(f'{details[i]}:{x[i]}')
    print(f'Matched {max(count_of_matches)*100/4}%')
def deletion():
    ID_of_the_person=int(input('Enter the unique ID: '))
    for i in existing_user:
        if ID_of_the_person in i:
            existing_user.remove(i)
    for j in existing_user:
        print()
        for k in range(len(details)):
            print(f'{details[k]}:{j[k]}')
print('Menu:')
print('0:To exit')
print('1:Insertion')
print('2:Modification')
print('3:Retrival')
print('4:Searching')
print('5:Recommedation')
print('6:Deletion')
while True:
    Req_process=int(input('Enter the process you required: '))
    if Req_process==0:
        print('Logout')
        break
    if Req_process==1:
        user_details=[]
        insertion()
        existing_user.append(user_details)
        print(existing_user)
    if Req_process==2:
        modification()
    if Req_process==3:
        ordered_list=[]
        retrival()
    if Req_process==4:
        searching()
    if Req_process==5:
        recommendation()
    if Req_process==6:
        deleted_val=[]
        deletion()
# Out:
# Menu:
# 0:To exit
# 1:Insertion
# 2:Modification
# 3:Retrival
# 4:Searching
# 5:Recommedation
# 6:Deletion
# Enter the process you required: 5
# Enter your gender:female
# Enter your age:25
# Enter your hobby:swimming
# Enter your dislike:nonveg
#
# Unique ID:10005
# Name:David
# Gender:Male
# Age:29
# Occupation:Electrical engineer
# salary:250000
# Hobby:Swimming
# Dislike:Nonveg
# Location:Trichy
# Matched 75.0%
# Enter the process you required: 2
# Enter the process you required: 3
#
# Unique ID:10001
# Name:Akash
# Gender:Male
# Age:26
# Occupation:Software engineer
# salary:100000
# Hobby:Reading books
# Dislike:Cakes
# Location:Bangalore
#
# Unique ID:10002
# Name:Anwar
# Gender:Male
# Age:28
# Occupation:Business
# salary:150000
# Hobby:Playing games
# Dislike:Advice
# Location:Chennai
#
# Unique ID:10005
# Name:David
# Gender:Male
# Age:29
# Occupation:Electrical engineer
# salary:250000
# Hobby:Swimming
# Dislike:Nonveg
# Location:Trichy
#
# Unique ID:10003
# Name:Malar
# ...
